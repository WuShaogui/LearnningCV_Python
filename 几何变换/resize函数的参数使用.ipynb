# %% [markdown]
# 本脚本展示如何使用cv2.resize

# %%
# 导入阅读代码工具
import sys
import os.path as osp
sys.path.append('/home/wushaogui/ReadCode/')
from my_read_code_tools import *

# %%
import cv2
import numpy as np

# %%
image_path='/home/wushaogui/ReadCode/Test/board.jpg'
image=cv2.imread(image_path)
print(image.shape)
show_images([image],imsize=6)
# Out:
# (480, 640, 3)

# %% [markdown]
# # 通过指定宽高进行resize

# %%
# let's downscale the image using new  width and height
down_width = 300
down_height = 200
down_points = (down_width, down_height)
resized_down = cv2.resize(image, down_points, interpolation= cv2.INTER_LINEAR)

# let's upscale the image using new  width and height
up_width = 600
up_height = 400
up_points = (up_width, up_height)
resized_up = cv2.resize(image, up_points, interpolation= cv2.INTER_LINEAR)
show_images([image,resized_down,resized_up],imsize=6)

# %% [markdown]
# # 通过指定缩放比例进行resize

# %%
# Scaling Up the image 1.2 times by specifying both scaling factors
scale_up_x = 1.5
scale_up_y = 1.5
# Scaling Down the image 0.6 times specifying a single scale factor.
scale_down = 0.5

scaled_f_down = cv2.resize(image, None, fx= scale_down, fy= scale_down, interpolation= cv2.INTER_LINEAR)
scaled_f_up = cv2.resize(image, None, fx= scale_up_x, fy= scale_up_y, interpolation= cv2.INTER_LINEAR)
show_images([image,scaled_f_down,scaled_f_up],imsize=6)

# %% [markdown]
# # 不同缩放方式的比价

# %%
down_width = 300
down_height = 200
down_points = (down_width, down_height)

resized_down_images=[]
for idx in range(7):
    resized_down = cv2.resize(image, down_points, interpolation= idx)
    resized_down_images.append(resized_down)
show_images(resized_down_images,nrows=1,imsize=6)

# %%
dst = cv2.resize(image,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_LINEAR)
show_images([image,dst])

dst = cv2.resize(image,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_NEAREST)
show_images([image,dst])

dst = cv2.resize(image,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_CUBIC)
show_images([image,dst])

dst = cv2.resize(image,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
show_images([image,dst])

dst = cv2.resize(image,None,fx=0.5,fy=0.5,interpolation=cv2.INTER_LANCZOS4)
show_images([image,dst])
